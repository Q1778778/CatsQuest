# %%
import  numpy

# %%
from PIL import Image

# %%
size=120, 120
im = Image.open("hit.jpg")
im_resized = im.resize(size, Image.ANTIALIAS)
im_resized.save("hit-120.jpg", "PNG")
image=im

# %%
image=Image.open("portal-fit.jpg").convert('RGBA')
if image.mode=="RGBA":
    image=image.convert('RGB')

# %%
m=numpy.asarray(image)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=45x45 at 0x10E3BD5D0>

# %%
m
# Out:
# array([[[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        ...,
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
# ...

# %%
import imageio

# %%
t=open('portal-fit.txt','w')

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = "," 
    
    # return string   
    return (str1.join(s))

# %%
import numpy as np

# %%
b=np.array(m).tolist()

# %%
b
# Out:
# [[[246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [248, 247, 247],
#   [248, 247, 246],
#   [247, 246, 246],
#   [247, 247, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246],
#   [246, 246, 246]],
#  [[246, 246, 246],
#   [246, 246, 246],
# ...

# %%
t.write(str(b))
# Out:
# 34491
